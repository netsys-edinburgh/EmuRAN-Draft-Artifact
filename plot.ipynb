# %% [markdown]
# # Reproduce and display the EmuRAN figures
#
# Each code cell independently runs one figure's plotting script from `results/data`, writes a fresh PDF to `results/output`, and displays that generated PDF inline. Figure labels correspond to the draft.

# %%
import os
import shutil
import subprocess
import sys
from pathlib import Path
from IPython.display import Image, Markdown, display

PROJECT_DIR = Path.cwd().resolve()
if not (PROJECT_DIR / "results").is_dir():
    raise RuntimeError(
        "Run this notebook from the EmuRAN-Draft-Artifact project root "
        "(the directory containing the results folder)."
    )
RESULTS_DIR = PROJECT_DIR / "results"
DATA_DIR = RESULTS_DIR / "data"
OUTPUT_DIR = RESULTS_DIR / "output"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
import pymupdf

figure_dir = DATA_DIR / 'fig2'
plot_script = figure_dir / 'gen_latencies_cdf.py'
output_pdf = OUTPUT_DIR / 'motivation.pdf'
output_pdf.unlink(missing_ok=True)
command = [sys.executable, str(plot_script)] + []
environment = os.environ.copy()
environment["MPLBACKEND"] = "Agg"
display(Markdown('## Draft Figure 2 — Compute interruption and network-latency CDFs across cloud providers' + f"\n\nRunning `{plot_script.relative_to(PROJECT_DIR)}`…"))
completed = subprocess.run(
    command,
    cwd=figure_dir,
    env=environment,
    text=True,
    capture_output=True,
)
if completed.returncode != 0:
    raise RuntimeError(
        f"Plot script failed with exit code {completed.returncode}:\n"
        f"{completed.stderr.strip() or completed.stdout.strip()}"
    )
if completed.stdout.strip():
    print(completed.stdout.strip())
produced_pdf = figure_dir / 'motivation.pdf'
if not produced_pdf.exists():
    raise FileNotFoundError(f"Plot script did not generate {produced_pdf}")
shutil.move(str(produced_pdf), str(output_pdf))
if not output_pdf.exists():
    raise FileNotFoundError(f"Expected generated PDF at {output_pdf}")

document = pymupdf.open(output_pdf)
for page in document:
    pixmap = page.get_pixmap(matrix=pymupdf.Matrix(2, 2), alpha=False)
    display(Image(data=pixmap.tobytes("png")))
document.close()
display(Markdown(f"Generated: `{output_pdf.relative_to(PROJECT_DIR)}`"))

# %%
import os
import shutil
import subprocess
import sys
from pathlib import Path
from IPython.display import Image, Markdown, display

PROJECT_DIR = Path.cwd().resolve()
if not (PROJECT_DIR / "results").is_dir():
    raise RuntimeError(
        "Run this notebook from the EmuRAN-Draft-Artifact project root "
        "(the directory containing the results folder)."
    )
RESULTS_DIR = PROJECT_DIR / "results"
DATA_DIR = RESULTS_DIR / "data"
OUTPUT_DIR = RESULTS_DIR / "output"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
import pymupdf

figure_dir = DATA_DIR / 'fig4b'
plot_script = figure_dir / 'plot.py'
output_pdf = OUTPUT_DIR / 'cpu_net_dual_axis_colored_ticks.pdf'
output_pdf.unlink(missing_ok=True)
command = [sys.executable, str(plot_script)] + []
environment = os.environ.copy()
environment["MPLBACKEND"] = "Agg"
display(Markdown('## Draft Figure 4(b) — CPU and network throughput for PHY bypass versus full-PHY emulation' + f"\n\nRunning `{plot_script.relative_to(PROJECT_DIR)}`…"))
completed = subprocess.run(
    command,
    cwd=figure_dir,
    env=environment,
    text=True,
    capture_output=True,
)
if completed.returncode != 0:
    raise RuntimeError(
        f"Plot script failed with exit code {completed.returncode}:\n"
        f"{completed.stderr.strip() or completed.stdout.strip()}"
    )
if completed.stdout.strip():
    print(completed.stdout.strip())
produced_pdf = figure_dir / 'cpu_net_dual_axis_colored_ticks.pdf'
if not produced_pdf.exists():
    raise FileNotFoundError(f"Plot script did not generate {produced_pdf}")
shutil.move(str(produced_pdf), str(output_pdf))
if not output_pdf.exists():
    raise FileNotFoundError(f"Expected generated PDF at {output_pdf}")

document = pymupdf.open(output_pdf)
for page in document:
    pixmap = page.get_pixmap(matrix=pymupdf.Matrix(2, 2), alpha=False)
    display(Image(data=pixmap.tobytes("png")))
document.close()
display(Markdown(f"Generated: `{output_pdf.relative_to(PROJECT_DIR)}`"))

# %%
import os
import shutil
import subprocess
import sys
from pathlib import Path
from IPython.display import Image, Markdown, display

PROJECT_DIR = Path.cwd().resolve()
if not (PROJECT_DIR / "results").is_dir():
    raise RuntimeError(
        "Run this notebook from the EmuRAN-Draft-Artifact project root "
        "(the directory containing the results folder)."
    )
RESULTS_DIR = PROJECT_DIR / "results"
DATA_DIR = RESULTS_DIR / "data"
OUTPUT_DIR = RESULTS_DIR / "output"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
import pymupdf

figure_dir = DATA_DIR / 'fig4c'
plot_script = figure_dir / 'plot_fig14.py'
output_pdf = OUTPUT_DIR / 'evaluation-hypervisor-prevent-overrunning.pdf'
output_pdf.unlink(missing_ok=True)
command = [sys.executable, str(plot_script)] + []
environment = os.environ.copy()
environment["MPLBACKEND"] = "Agg"
display(Markdown('## Draft Figure 4(c) — Virtualized task time with and without Chronos' + f"\n\nRunning `{plot_script.relative_to(PROJECT_DIR)}`…"))
completed = subprocess.run(
    command,
    cwd=figure_dir,
    env=environment,
    text=True,
    capture_output=True,
)
if completed.returncode != 0:
    raise RuntimeError(
        f"Plot script failed with exit code {completed.returncode}:\n"
        f"{completed.stderr.strip() or completed.stdout.strip()}"
    )
if completed.stdout.strip():
    print(completed.stdout.strip())
produced_pdf = figure_dir / 'evaluation-hypervisor-prevent-overrunning.pdf'
if not produced_pdf.exists():
    raise FileNotFoundError(f"Plot script did not generate {produced_pdf}")
shutil.move(str(produced_pdf), str(output_pdf))
if not output_pdf.exists():
    raise FileNotFoundError(f"Expected generated PDF at {output_pdf}")

document = pymupdf.open(output_pdf)
for page in document:
    pixmap = page.get_pixmap(matrix=pymupdf.Matrix(2, 2), alpha=False)
    display(Image(data=pixmap.tobytes("png")))
document.close()
display(Markdown(f"Generated: `{output_pdf.relative_to(PROJECT_DIR)}`"))

# %%
import os
import shutil
import subprocess
import sys
from pathlib import Path
from IPython.display import Image, Markdown, display

PROJECT_DIR = Path.cwd().resolve()
if not (PROJECT_DIR / "results").is_dir():
    raise RuntimeError(
        "Run this notebook from the EmuRAN-Draft-Artifact project root "
        "(the directory containing the results folder)."
    )
RESULTS_DIR = PROJECT_DIR / "results"
DATA_DIR = RESULTS_DIR / "data"
OUTPUT_DIR = RESULTS_DIR / "output"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
import pymupdf

figure_dir = DATA_DIR / 'fig4d'
plot_script = figure_dir / 'plot.py'
output_pdf = OUTPUT_DIR / 'design-slot-checker-sync.pdf'
output_pdf.unlink(missing_ok=True)
command = [sys.executable, str(plot_script)] + []
environment = os.environ.copy()
environment["MPLBACKEND"] = "Agg"
display(Markdown('## Draft Figure 4(d) — Slot Coordinator synchronization behavior' + f"\n\nRunning `{plot_script.relative_to(PROJECT_DIR)}`…"))
completed = subprocess.run(
    command,
    cwd=figure_dir,
    env=environment,
    text=True,
    capture_output=True,
)
if completed.returncode != 0:
    raise RuntimeError(
        f"Plot script failed with exit code {completed.returncode}:\n"
        f"{completed.stderr.strip() or completed.stdout.strip()}"
    )
if completed.stdout.strip():
    print(completed.stdout.strip())
produced_pdf = figure_dir / 'design-slot-checker-sync.pdf'
if not produced_pdf.exists():
    raise FileNotFoundError(f"Plot script did not generate {produced_pdf}")
shutil.move(str(produced_pdf), str(output_pdf))
if not output_pdf.exists():
    raise FileNotFoundError(f"Expected generated PDF at {output_pdf}")

document = pymupdf.open(output_pdf)
for page in document:
    pixmap = page.get_pixmap(matrix=pymupdf.Matrix(2, 2), alpha=False)
    display(Image(data=pixmap.tobytes("png")))
document.close()
display(Markdown(f"Generated: `{output_pdf.relative_to(PROJECT_DIR)}`"))

# %%
import os
import shutil
import subprocess
import sys
from pathlib import Path
from IPython.display import Image, Markdown, display

PROJECT_DIR = Path.cwd().resolve()
if not (PROJECT_DIR / "results").is_dir():
    raise RuntimeError(
        "Run this notebook from the EmuRAN-Draft-Artifact project root "
        "(the directory containing the results folder)."
    )
RESULTS_DIR = PROJECT_DIR / "results"
DATA_DIR = RESULTS_DIR / "data"
OUTPUT_DIR = RESULTS_DIR / "output"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
import pymupdf

figure_dir = DATA_DIR / 'fig5'
plot_script = figure_dir / 'plot_cbra_timeline_no_table.py'
output_pdf = OUTPUT_DIR / 'cbra_timeline_no_table.pdf'
output_pdf.unlink(missing_ok=True)
command = [sys.executable, str(plot_script)] + ['--output', str(output_pdf)]
environment = os.environ.copy()
environment["MPLBACKEND"] = "Agg"
display(Markdown('## Draft Figure 5 — Control-plane fidelity: CBRA ACK/NACK timeline' + f"\n\nRunning `{plot_script.relative_to(PROJECT_DIR)}`…"))
completed = subprocess.run(
    command,
    cwd=figure_dir,
    env=environment,
    text=True,
    capture_output=True,
)
if completed.returncode != 0:
    raise RuntimeError(
        f"Plot script failed with exit code {completed.returncode}:\n"
        f"{completed.stderr.strip() or completed.stdout.strip()}"
    )
if completed.stdout.strip():
    print(completed.stdout.strip())
if not output_pdf.exists():
    raise FileNotFoundError(f"Expected generated PDF at {output_pdf}")

document = pymupdf.open(output_pdf)
for page in document:
    pixmap = page.get_pixmap(matrix=pymupdf.Matrix(2, 2), alpha=False)
    display(Image(data=pixmap.tobytes("png")))
document.close()
display(Markdown(f"Generated: `{output_pdf.relative_to(PROJECT_DIR)}`"))

# %%
import os
import shutil
import subprocess
import sys
from pathlib import Path
from IPython.display import Image, Markdown, display

PROJECT_DIR = Path.cwd().resolve()
if not (PROJECT_DIR / "results").is_dir():
    raise RuntimeError(
        "Run this notebook from the EmuRAN-Draft-Artifact project root "
        "(the directory containing the results folder)."
    )
RESULTS_DIR = PROJECT_DIR / "results"
DATA_DIR = RESULTS_DIR / "data"
OUTPUT_DIR = RESULTS_DIR / "output"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
import pymupdf

figure_dir = DATA_DIR / 'fig6'
plot_script = figure_dir / 'plot_throughput_stacked.py'
output_pdf = OUTPUT_DIR / 'throughput_stacked.pdf'
output_pdf.unlink(missing_ok=True)
command = [sys.executable, str(plot_script)] + ['--output', str(output_pdf)]
environment = os.environ.copy()
environment["MPLBACKEND"] = "Agg"
display(Markdown('## Draft Figure 6(a–b) — Combined data-plane fidelity results' + f"\n\nRunning `{plot_script.relative_to(PROJECT_DIR)}`…"))
completed = subprocess.run(
    command,
    cwd=figure_dir,
    env=environment,
    text=True,
    capture_output=True,
)
if completed.returncode != 0:
    raise RuntimeError(
        f"Plot script failed with exit code {completed.returncode}:\n"
        f"{completed.stderr.strip() or completed.stdout.strip()}"
    )
if completed.stdout.strip():
    print(completed.stdout.strip())
if not output_pdf.exists():
    raise FileNotFoundError(f"Expected generated PDF at {output_pdf}")

document = pymupdf.open(output_pdf)
for page in document:
    pixmap = page.get_pixmap(matrix=pymupdf.Matrix(2, 2), alpha=False)
    display(Image(data=pixmap.tobytes("png")))
document.close()
display(Markdown(f"Generated: `{output_pdf.relative_to(PROJECT_DIR)}`"))

# %%
import os
import shutil
import subprocess
import sys
from pathlib import Path
from IPython.display import Image, Markdown, display

PROJECT_DIR = Path.cwd().resolve()
if not (PROJECT_DIR / "results").is_dir():
    raise RuntimeError(
        "Run this notebook from the EmuRAN-Draft-Artifact project root "
        "(the directory containing the results folder)."
    )
RESULTS_DIR = PROJECT_DIR / "results"
DATA_DIR = RESULTS_DIR / "data"
OUTPUT_DIR = RESULTS_DIR / "output"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
import pymupdf

figure_dir = DATA_DIR / 'fig7(a-d)'
plot_script = figure_dir / 'plot_link_adaptation_sinr.py'
output_pdf = OUTPUT_DIR / 'emuran_sinr_panel_a_mcs_goodput.pdf'
output_pdf.unlink(missing_ok=True)
command = [sys.executable, str(plot_script)] + []
environment = os.environ.copy()
environment["MPLBACKEND"] = "Agg"
display(Markdown('## Draft Figure 7(a) — Settled MCS and DL goodput versus SINR' + f"\n\nRunning `{plot_script.relative_to(PROJECT_DIR)}`…"))
completed = subprocess.run(
    command,
    cwd=figure_dir,
    env=environment,
    text=True,
    capture_output=True,
)
if completed.returncode != 0:
    raise RuntimeError(
        f"Plot script failed with exit code {completed.returncode}:\n"
        f"{completed.stderr.strip() or completed.stdout.strip()}"
    )
if completed.stdout.strip():
    print(completed.stdout.strip())
for produced_pdf in figure_dir.glob("emuran_sinr_panel_*.pdf"):
    shutil.move(str(produced_pdf), str(OUTPUT_DIR / produced_pdf.name))
if not output_pdf.exists():
    raise FileNotFoundError(f"Expected generated PDF at {output_pdf}")

document = pymupdf.open(output_pdf)
for page in document:
    pixmap = page.get_pixmap(matrix=pymupdf.Matrix(2, 2), alpha=False)
    display(Image(data=pixmap.tobytes("png")))
document.close()
display(Markdown(f"Generated: `{output_pdf.relative_to(PROJECT_DIR)}`"))

# %%
import os
import shutil
import subprocess
import sys
from pathlib import Path
from IPython.display import Image, Markdown, display

PROJECT_DIR = Path.cwd().resolve()
if not (PROJECT_DIR / "results").is_dir():
    raise RuntimeError(
        "Run this notebook from the EmuRAN-Draft-Artifact project root "
        "(the directory containing the results folder)."
    )
RESULTS_DIR = PROJECT_DIR / "results"
DATA_DIR = RESULTS_DIR / "data"
OUTPUT_DIR = RESULTS_DIR / "output"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
import pymupdf

figure_dir = DATA_DIR / 'fig7(a-d)'
plot_script = figure_dir / 'plot_link_adaptation_sinr.py'
output_pdf = OUTPUT_DIR / 'emuran_sinr_panel_b_cwnd.pdf'
output_pdf.unlink(missing_ok=True)
command = [sys.executable, str(plot_script)] + []
environment = os.environ.copy()
environment["MPLBACKEND"] = "Agg"
display(Markdown('## Draft Figure 7(b) — Congestion-window evolution' + f"\n\nRunning `{plot_script.relative_to(PROJECT_DIR)}`…"))
completed = subprocess.run(
    command,
    cwd=figure_dir,
    env=environment,
    text=True,
    capture_output=True,
)
if completed.returncode != 0:
    raise RuntimeError(
        f"Plot script failed with exit code {completed.returncode}:\n"
        f"{completed.stderr.strip() or completed.stdout.strip()}"
    )
if completed.stdout.strip():
    print(completed.stdout.strip())
for produced_pdf in figure_dir.glob("emuran_sinr_panel_*.pdf"):
    shutil.move(str(produced_pdf), str(OUTPUT_DIR / produced_pdf.name))
if not output_pdf.exists():
    raise FileNotFoundError(f"Expected generated PDF at {output_pdf}")

document = pymupdf.open(output_pdf)
for page in document:
    pixmap = page.get_pixmap(matrix=pymupdf.Matrix(2, 2), alpha=False)
    display(Image(data=pixmap.tobytes("png")))
document.close()
display(Markdown(f"Generated: `{output_pdf.relative_to(PROJECT_DIR)}`"))

# %%
import os
import shutil
import subprocess
import sys
from pathlib import Path
from IPython.display import Image, Markdown, display

PROJECT_DIR = Path.cwd().resolve()
if not (PROJECT_DIR / "results").is_dir():
    raise RuntimeError(
        "Run this notebook from the EmuRAN-Draft-Artifact project root "
        "(the directory containing the results folder)."
    )
RESULTS_DIR = PROJECT_DIR / "results"
DATA_DIR = RESULTS_DIR / "data"
OUTPUT_DIR = RESULTS_DIR / "output"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
import pymupdf

figure_dir = DATA_DIR / 'fig7(a-d)'
plot_script = figure_dir / 'plot_link_adaptation_sinr.py'
output_pdf = OUTPUT_DIR / 'emuran_sinr_panel_c_bler.pdf'
output_pdf.unlink(missing_ok=True)
command = [sys.executable, str(plot_script)] + []
environment = os.environ.copy()
environment["MPLBACKEND"] = "Agg"
display(Markdown('## Draft Figure 7(c) — BLER evolution' + f"\n\nRunning `{plot_script.relative_to(PROJECT_DIR)}`…"))
completed = subprocess.run(
    command,
    cwd=figure_dir,
    env=environment,
    text=True,
    capture_output=True,
)
if completed.returncode != 0:
    raise RuntimeError(
        f"Plot script failed with exit code {completed.returncode}:\n"
        f"{completed.stderr.strip() or completed.stdout.strip()}"
    )
if completed.stdout.strip():
    print(completed.stdout.strip())
for produced_pdf in figure_dir.glob("emuran_sinr_panel_*.pdf"):
    shutil.move(str(produced_pdf), str(OUTPUT_DIR / produced_pdf.name))
if not output_pdf.exists():
    raise FileNotFoundError(f"Expected generated PDF at {output_pdf}")

document = pymupdf.open(output_pdf)
for page in document:
    pixmap = page.get_pixmap(matrix=pymupdf.Matrix(2, 2), alpha=False)
    display(Image(data=pixmap.tobytes("png")))
document.close()
display(Markdown(f"Generated: `{output_pdf.relative_to(PROJECT_DIR)}`"))

# %%
import os
import shutil
import subprocess
import sys
from pathlib import Path
from IPython.display import Image, Markdown, display

PROJECT_DIR = Path.cwd().resolve()
if not (PROJECT_DIR / "results").is_dir():
    raise RuntimeError(
        "Run this notebook from the EmuRAN-Draft-Artifact project root "
        "(the directory containing the results folder)."
    )
RESULTS_DIR = PROJECT_DIR / "results"
DATA_DIR = RESULTS_DIR / "data"
OUTPUT_DIR = RESULTS_DIR / "output"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
import pymupdf

figure_dir = DATA_DIR / 'fig7(a-d)'
plot_script = figure_dir / 'plot_link_adaptation_sinr.py'
output_pdf = OUTPUT_DIR / 'emuran_sinr_panel_d_harq.pdf'
output_pdf.unlink(missing_ok=True)
command = [sys.executable, str(plot_script)] + []
environment = os.environ.copy()
environment["MPLBACKEND"] = "Agg"
display(Markdown('## Draft Figure 7(d) — Total HARQ retransmissions' + f"\n\nRunning `{plot_script.relative_to(PROJECT_DIR)}`…"))
completed = subprocess.run(
    command,
    cwd=figure_dir,
    env=environment,
    text=True,
    capture_output=True,
)
if completed.returncode != 0:
    raise RuntimeError(
        f"Plot script failed with exit code {completed.returncode}:\n"
        f"{completed.stderr.strip() or completed.stdout.strip()}"
    )
if completed.stdout.strip():
    print(completed.stdout.strip())
for produced_pdf in figure_dir.glob("emuran_sinr_panel_*.pdf"):
    shutil.move(str(produced_pdf), str(OUTPUT_DIR / produced_pdf.name))
if not output_pdf.exists():
    raise FileNotFoundError(f"Expected generated PDF at {output_pdf}")

document = pymupdf.open(output_pdf)
for page in document:
    pixmap = page.get_pixmap(matrix=pymupdf.Matrix(2, 2), alpha=False)
    display(Image(data=pixmap.tobytes("png")))
document.close()
display(Markdown(f"Generated: `{output_pdf.relative_to(PROJECT_DIR)}`"))

# %%
import os
import shutil
import subprocess
import sys
from pathlib import Path
from IPython.display import Image, Markdown, display

PROJECT_DIR = Path.cwd().resolve()
if not (PROJECT_DIR / "results").is_dir():
    raise RuntimeError(
        "Run this notebook from the EmuRAN-Draft-Artifact project root "
        "(the directory containing the results folder)."
    )
RESULTS_DIR = PROJECT_DIR / "results"
DATA_DIR = RESULTS_DIR / "data"
OUTPUT_DIR = RESULTS_DIR / "output"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
import pymupdf

figure_dir = DATA_DIR / 'fig8a'
plot_script = figure_dir / 'plot_ping_avg_bar.py'
output_pdf = OUTPUT_DIR / 'ping_avg_bar.pdf'
output_pdf.unlink(missing_ok=True)
command = [sys.executable, str(plot_script)] + ['--output', str(output_pdf)]
environment = os.environ.copy()
environment["MPLBACKEND"] = "Agg"
display(Markdown('## Draft Figure 8(a) — ICMP RTT under two MAC scheduler configurations' + f"\n\nRunning `{plot_script.relative_to(PROJECT_DIR)}`…"))
completed = subprocess.run(
    command,
    cwd=figure_dir,
    env=environment,
    text=True,
    capture_output=True,
)
if completed.returncode != 0:
    raise RuntimeError(
        f"Plot script failed with exit code {completed.returncode}:\n"
        f"{completed.stderr.strip() or completed.stdout.strip()}"
    )
if completed.stdout.strip():
    print(completed.stdout.strip())
if not output_pdf.exists():
    raise FileNotFoundError(f"Expected generated PDF at {output_pdf}")

document = pymupdf.open(output_pdf)
for page in document:
    pixmap = page.get_pixmap(matrix=pymupdf.Matrix(2, 2), alpha=False)
    display(Image(data=pixmap.tobytes("png")))
document.close()
display(Markdown(f"Generated: `{output_pdf.relative_to(PROJECT_DIR)}`"))

# %%
import os
import shutil
import subprocess
import sys
from pathlib import Path
from IPython.display import Image, Markdown, display

PROJECT_DIR = Path.cwd().resolve()
if not (PROJECT_DIR / "results").is_dir():
    raise RuntimeError(
        "Run this notebook from the EmuRAN-Draft-Artifact project root "
        "(the directory containing the results folder)."
    )
RESULTS_DIR = PROJECT_DIR / "results"
DATA_DIR = RESULTS_DIR / "data"
OUTPUT_DIR = RESULTS_DIR / "output"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
import pymupdf

figure_dir = DATA_DIR / 'fig8b'
plot_script = figure_dir / 'fig8b.py'
output_pdf = OUTPUT_DIR / 'dilation_compute_throughput.pdf'
output_pdf.unlink(missing_ok=True)
command = [sys.executable, str(plot_script)] + []
environment = os.environ.copy()
environment["MPLBACKEND"] = "Agg"
display(Markdown('## Draft Figure 8(b) — Scale, data-plane fidelity, and dilation factor' + f"\n\nRunning `{plot_script.relative_to(PROJECT_DIR)}`…"))
completed = subprocess.run(
    command,
    cwd=figure_dir,
    env=environment,
    text=True,
    capture_output=True,
)
if completed.returncode != 0:
    raise RuntimeError(
        f"Plot script failed with exit code {completed.returncode}:\n"
        f"{completed.stderr.strip() or completed.stdout.strip()}"
    )
if completed.stdout.strip():
    print(completed.stdout.strip())
produced_pdf = figure_dir / 'dilation_compute_throughput.pdf'
if not produced_pdf.exists():
    raise FileNotFoundError(f"Plot script did not generate {produced_pdf}")
shutil.move(str(produced_pdf), str(output_pdf))
if not output_pdf.exists():
    raise FileNotFoundError(f"Expected generated PDF at {output_pdf}")

document = pymupdf.open(output_pdf)
for page in document:
    pixmap = page.get_pixmap(matrix=pymupdf.Matrix(2, 2), alpha=False)
    display(Image(data=pixmap.tobytes("png")))
document.close()
display(Markdown(f"Generated: `{output_pdf.relative_to(PROJECT_DIR)}`"))

# %%
import os
import shutil
import subprocess
import sys
from pathlib import Path
from IPython.display import Image, Markdown, display

PROJECT_DIR = Path.cwd().resolve()
if not (PROJECT_DIR / "results").is_dir():
    raise RuntimeError(
        "Run this notebook from the EmuRAN-Draft-Artifact project root "
        "(the directory containing the results folder)."
    )
RESULTS_DIR = PROJECT_DIR / "results"
DATA_DIR = RESULTS_DIR / "data"
OUTPUT_DIR = RESULTS_DIR / "output"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
import pymupdf

figure_dir = DATA_DIR / 'fig8c'
plot_script = figure_dir / 'fig8c_small_v2_with_gnb_axis.py'
output_pdf = OUTPUT_DIR / 'fig8c_small_v2.pdf'
output_pdf.unlink(missing_ok=True)
command = [sys.executable, str(plot_script)] + []
environment = os.environ.copy()
environment["MPLBACKEND"] = "Agg"
display(Markdown('## Draft Figure 8(c) — Multi-UE-per-gNB scaling and dilation factor' + f"\n\nRunning `{plot_script.relative_to(PROJECT_DIR)}`…"))
completed = subprocess.run(
    command,
    cwd=figure_dir,
    env=environment,
    text=True,
    capture_output=True,
)
if completed.returncode != 0:
    raise RuntimeError(
        f"Plot script failed with exit code {completed.returncode}:\n"
        f"{completed.stderr.strip() or completed.stdout.strip()}"
    )
if completed.stdout.strip():
    print(completed.stdout.strip())
produced_pdf = figure_dir / 'fig8c_small_v2.pdf'
if not produced_pdf.exists():
    raise FileNotFoundError(f"Plot script did not generate {produced_pdf}")
shutil.move(str(produced_pdf), str(output_pdf))
if not output_pdf.exists():
    raise FileNotFoundError(f"Expected generated PDF at {output_pdf}")

document = pymupdf.open(output_pdf)
for page in document:
    pixmap = page.get_pixmap(matrix=pymupdf.Matrix(2, 2), alpha=False)
    display(Image(data=pixmap.tobytes("png")))
document.close()
display(Markdown(f"Generated: `{output_pdf.relative_to(PROJECT_DIR)}`"))

# %%
import os
import shutil
import subprocess
import sys
from pathlib import Path
from IPython.display import Image, Markdown, display

PROJECT_DIR = Path.cwd().resolve()
if not (PROJECT_DIR / "results").is_dir():
    raise RuntimeError(
        "Run this notebook from the EmuRAN-Draft-Artifact project root "
        "(the directory containing the results folder)."
    )
RESULTS_DIR = PROJECT_DIR / "results"
DATA_DIR = RESULTS_DIR / "data"
OUTPUT_DIR = RESULTS_DIR / "output"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
import pymupdf

figure_dir = DATA_DIR / 'fig9a'
plot_script = figure_dir / 'plot.py'
output_pdf = OUTPUT_DIR / 'scalability-chronos-vs-emane-data-plane.pdf'
output_pdf.unlink(missing_ok=True)
command = [sys.executable, str(plot_script)] + []
environment = os.environ.copy()
environment["MPLBACKEND"] = "Agg"
display(Markdown('## Draft Figure 9(a) — Average UE RTT scaling: Chronos versus EMANE' + f"\n\nRunning `{plot_script.relative_to(PROJECT_DIR)}`…"))
completed = subprocess.run(
    command,
    cwd=figure_dir,
    env=environment,
    text=True,
    capture_output=True,
)
if completed.returncode != 0:
    raise RuntimeError(
        f"Plot script failed with exit code {completed.returncode}:\n"
        f"{completed.stderr.strip() or completed.stdout.strip()}"
    )
if completed.stdout.strip():
    print(completed.stdout.strip())
produced_pdf = figure_dir / 'scalability-chronos-vs-emane-data-plane.pdf'
if not produced_pdf.exists():
    raise FileNotFoundError(f"Plot script did not generate {produced_pdf}")
shutil.move(str(produced_pdf), str(output_pdf))
if not output_pdf.exists():
    raise FileNotFoundError(f"Expected generated PDF at {output_pdf}")

document = pymupdf.open(output_pdf)
for page in document:
    pixmap = page.get_pixmap(matrix=pymupdf.Matrix(2, 2), alpha=False)
    display(Image(data=pixmap.tobytes("png")))
document.close()
display(Markdown(f"Generated: `{output_pdf.relative_to(PROJECT_DIR)}`"))

# %%
import os
import shutil
import subprocess
import sys
from pathlib import Path
from IPython.display import Image, Markdown, display

PROJECT_DIR = Path.cwd().resolve()
if not (PROJECT_DIR / "results").is_dir():
    raise RuntimeError(
        "Run this notebook from the EmuRAN-Draft-Artifact project root "
        "(the directory containing the results folder)."
    )
RESULTS_DIR = PROJECT_DIR / "results"
DATA_DIR = RESULTS_DIR / "data"
OUTPUT_DIR = RESULTS_DIR / "output"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
import pymupdf

figure_dir = DATA_DIR / 'fig9b'
plot_script = figure_dir / 'plot.py'
output_pdf = OUTPUT_DIR / 'scalability-chronos-vs-emane.pdf'
output_pdf.unlink(missing_ok=True)
command = [sys.executable, str(plot_script)] + []
environment = os.environ.copy()
environment["MPLBACKEND"] = "Agg"
display(Markdown('## Draft Figure 9(b) — Successfully connected UEs: Chronos versus EMANE' + f"\n\nRunning `{plot_script.relative_to(PROJECT_DIR)}`…"))
completed = subprocess.run(
    command,
    cwd=figure_dir,
    env=environment,
    text=True,
    capture_output=True,
)
if completed.returncode != 0:
    raise RuntimeError(
        f"Plot script failed with exit code {completed.returncode}:\n"
        f"{completed.stderr.strip() or completed.stdout.strip()}"
    )
if completed.stdout.strip():
    print(completed.stdout.strip())
produced_pdf = figure_dir / 'scalability-chronos-vs-emane.pdf'
if not produced_pdf.exists():
    raise FileNotFoundError(f"Plot script did not generate {produced_pdf}")
shutil.move(str(produced_pdf), str(output_pdf))
if not output_pdf.exists():
    raise FileNotFoundError(f"Expected generated PDF at {output_pdf}")

document = pymupdf.open(output_pdf)
for page in document:
    pixmap = page.get_pixmap(matrix=pymupdf.Matrix(2, 2), alpha=False)
    display(Image(data=pixmap.tobytes("png")))
document.close()
display(Markdown(f"Generated: `{output_pdf.relative_to(PROJECT_DIR)}`"))

# %%
import os
import shutil
import subprocess
import sys
from pathlib import Path
from IPython.display import Image, Markdown, display

PROJECT_DIR = Path.cwd().resolve()
if not (PROJECT_DIR / "results").is_dir():
    raise RuntimeError(
        "Run this notebook from the EmuRAN-Draft-Artifact project root "
        "(the directory containing the results folder)."
    )
RESULTS_DIR = PROJECT_DIR / "results"
DATA_DIR = RESULTS_DIR / "data"
OUTPUT_DIR = RESULTS_DIR / "output"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
import pymupdf

figure_dir = DATA_DIR / 'fig9c'
plot_script = figure_dir / 'plot.py'
output_pdf = OUTPUT_DIR / 'evaluation-globalsc-cdf-and-dilation-factor.pdf'
output_pdf.unlink(missing_ok=True)
command = [sys.executable, str(plot_script)] + ['--output', str(output_pdf)]
environment = os.environ.copy()
environment["MPLBACKEND"] = "Agg"
display(Markdown('## Draft Figure 9(c) — Barrier arrivals and dilation factor' + f"\n\nRunning `{plot_script.relative_to(PROJECT_DIR)}`…"))
completed = subprocess.run(
    command,
    cwd=figure_dir,
    env=environment,
    text=True,
    capture_output=True,
)
if completed.returncode != 0:
    raise RuntimeError(
        f"Plot script failed with exit code {completed.returncode}:\n"
        f"{completed.stderr.strip() or completed.stdout.strip()}"
    )
if completed.stdout.strip():
    print(completed.stdout.strip())
if not output_pdf.exists():
    raise FileNotFoundError(f"Expected generated PDF at {output_pdf}")

document = pymupdf.open(output_pdf)
for page in document:
    pixmap = page.get_pixmap(matrix=pymupdf.Matrix(2, 2), alpha=False)
    display(Image(data=pixmap.tobytes("png")))
document.close()
display(Markdown(f"Generated: `{output_pdf.relative_to(PROJECT_DIR)}`"))

# %%
import os
import shutil
import subprocess
import sys
from pathlib import Path
from IPython.display import Image, Markdown, display

PROJECT_DIR = Path.cwd().resolve()
if not (PROJECT_DIR / "results").is_dir():
    raise RuntimeError(
        "Run this notebook from the EmuRAN-Draft-Artifact project root "
        "(the directory containing the results folder)."
    )
RESULTS_DIR = PROJECT_DIR / "results"
DATA_DIR = RESULTS_DIR / "data"
OUTPUT_DIR = RESULTS_DIR / "output"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
import pymupdf

figure_dir = DATA_DIR / 'fig9d'
plot_script = figure_dir / 'plot.py'
output_pdf = OUTPUT_DIR / 'evaluation-cloud-split-proxy.pdf'
output_pdf.unlink(missing_ok=True)
command = [sys.executable, str(plot_script)] + []
environment = os.environ.copy()
environment["MPLBACKEND"] = "Agg"
display(Markdown('## Draft Figure 9(d) — Distributed cloud split/proxy evaluation' + f"\n\nRunning `{plot_script.relative_to(PROJECT_DIR)}`…"))
completed = subprocess.run(
    command,
    cwd=figure_dir,
    env=environment,
    text=True,
    capture_output=True,
)
if completed.returncode != 0:
    raise RuntimeError(
        f"Plot script failed with exit code {completed.returncode}:\n"
        f"{completed.stderr.strip() or completed.stdout.strip()}"
    )
if completed.stdout.strip():
    print(completed.stdout.strip())
produced_pdf = figure_dir / 'evaluation-cloud-split-proxy.pdf'
if not produced_pdf.exists():
    raise FileNotFoundError(f"Plot script did not generate {produced_pdf}")
shutil.move(str(produced_pdf), str(output_pdf))
if not output_pdf.exists():
    raise FileNotFoundError(f"Expected generated PDF at {output_pdf}")

document = pymupdf.open(output_pdf)
for page in document:
    pixmap = page.get_pixmap(matrix=pymupdf.Matrix(2, 2), alpha=False)
    display(Image(data=pixmap.tobytes("png")))
document.close()
display(Markdown(f"Generated: `{output_pdf.relative_to(PROJECT_DIR)}`"))

# %%
import os
import shutil
import subprocess
import sys
from pathlib import Path
from IPython.display import Image, Markdown, display

PROJECT_DIR = Path.cwd().resolve()
if not (PROJECT_DIR / "results").is_dir():
    raise RuntimeError(
        "Run this notebook from the EmuRAN-Draft-Artifact project root "
        "(the directory containing the results folder)."
    )
RESULTS_DIR = PROJECT_DIR / "results"
DATA_DIR = RESULTS_DIR / "data"
OUTPUT_DIR = RESULTS_DIR / "output"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
import pymupdf

figure_dir = DATA_DIR / 'fig10a'
plot_script = figure_dir / 'plot-fig.py'
output_pdf = OUTPUT_DIR / 'emane_cdf.pdf'
output_pdf.unlink(missing_ok=True)
command = [sys.executable, str(plot_script)] + ['EMANE.csv', 'EmuRAN.csv']
environment = os.environ.copy()
environment["MPLBACKEND"] = "Agg"
display(Markdown('## Draft Figure 10(a) — Distributed Chronos versus monolithic EMANE processing tail' + f"\n\nRunning `{plot_script.relative_to(PROJECT_DIR)}`…"))
completed = subprocess.run(
    command,
    cwd=figure_dir,
    env=environment,
    text=True,
    capture_output=True,
)
if completed.returncode != 0:
    raise RuntimeError(
        f"Plot script failed with exit code {completed.returncode}:\n"
        f"{completed.stderr.strip() or completed.stdout.strip()}"
    )
if completed.stdout.strip():
    print(completed.stdout.strip())
produced_pdf = figure_dir / 'emane_cdf.pdf'
if not produced_pdf.exists():
    raise FileNotFoundError(f"Plot script did not generate {produced_pdf}")
shutil.move(str(produced_pdf), str(output_pdf))
if not output_pdf.exists():
    raise FileNotFoundError(f"Expected generated PDF at {output_pdf}")

document = pymupdf.open(output_pdf)
for page in document:
    pixmap = page.get_pixmap(matrix=pymupdf.Matrix(2, 2), alpha=False)
    display(Image(data=pixmap.tobytes("png")))
document.close()
display(Markdown(f"Generated: `{output_pdf.relative_to(PROJECT_DIR)}`"))

# %%
import os
import shutil
import subprocess
import sys
from pathlib import Path
from IPython.display import Image, Markdown, display

PROJECT_DIR = Path.cwd().resolve()
if not (PROJECT_DIR / "results").is_dir():
    raise RuntimeError(
        "Run this notebook from the EmuRAN-Draft-Artifact project root "
        "(the directory containing the results folder)."
    )
RESULTS_DIR = PROJECT_DIR / "results"
DATA_DIR = RESULTS_DIR / "data"
OUTPUT_DIR = RESULTS_DIR / "output"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
import pymupdf

figure_dir = DATA_DIR / 'fig10b'
plot_script = figure_dir / 'plot.py'
output_pdf = OUTPUT_DIR / 'controlvsazure.pdf'
output_pdf.unlink(missing_ok=True)
command = [sys.executable, str(plot_script)] + []
environment = os.environ.copy()
environment["MPLBACKEND"] = "Agg"
display(Markdown('## Draft Figure 10(b) — Controlled testbed versus Azure fidelity' + f"\n\nRunning `{plot_script.relative_to(PROJECT_DIR)}`…"))
completed = subprocess.run(
    command,
    cwd=figure_dir,
    env=environment,
    text=True,
    capture_output=True,
)
if completed.returncode != 0:
    raise RuntimeError(
        f"Plot script failed with exit code {completed.returncode}:\n"
        f"{completed.stderr.strip() or completed.stdout.strip()}"
    )
if completed.stdout.strip():
    print(completed.stdout.strip())
produced_pdf = figure_dir / 'controlvsazure.pdf'
if not produced_pdf.exists():
    raise FileNotFoundError(f"Plot script did not generate {produced_pdf}")
shutil.move(str(produced_pdf), str(output_pdf))
if not output_pdf.exists():
    raise FileNotFoundError(f"Expected generated PDF at {output_pdf}")

document = pymupdf.open(output_pdf)
for page in document:
    pixmap = page.get_pixmap(matrix=pymupdf.Matrix(2, 2), alpha=False)
    display(Image(data=pixmap.tobytes("png")))
document.close()
display(Markdown(f"Generated: `{output_pdf.relative_to(PROJECT_DIR)}`"))

# %%
import os
import shutil
import subprocess
import sys
from pathlib import Path
from IPython.display import Image, Markdown, display

PROJECT_DIR = Path.cwd().resolve()
if not (PROJECT_DIR / "results").is_dir():
    raise RuntimeError(
        "Run this notebook from the EmuRAN-Draft-Artifact project root "
        "(the directory containing the results folder)."
    )
RESULTS_DIR = PROJECT_DIR / "results"
DATA_DIR = RESULTS_DIR / "data"
OUTPUT_DIR = RESULTS_DIR / "output"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
import pymupdf

figure_dir = DATA_DIR / 'fig10c'
plot_script = figure_dir / 'plot_ping_latency_and_dilation.py'
output_pdf = OUTPUT_DIR / 'evaluation-dilation-compute-preemptions.pdf'
output_pdf.unlink(missing_ok=True)
command = [sys.executable, str(plot_script)] + []
environment = os.environ.copy()
environment["MPLBACKEND"] = "Agg"
display(Markdown('## Draft Figure 10(c) — Dilation under compute preemptions' + f"\n\nRunning `{plot_script.relative_to(PROJECT_DIR)}`…"))
completed = subprocess.run(
    command,
    cwd=figure_dir,
    env=environment,
    text=True,
    capture_output=True,
)
if completed.returncode != 0:
    raise RuntimeError(
        f"Plot script failed with exit code {completed.returncode}:\n"
        f"{completed.stderr.strip() or completed.stdout.strip()}"
    )
if completed.stdout.strip():
    print(completed.stdout.strip())
produced_pdf = figure_dir / 'evaluation-dilation-compute-preemptions.pdf'
if not produced_pdf.exists():
    raise FileNotFoundError(f"Plot script did not generate {produced_pdf}")
shutil.move(str(produced_pdf), str(output_pdf))
if not output_pdf.exists():
    raise FileNotFoundError(f"Expected generated PDF at {output_pdf}")

document = pymupdf.open(output_pdf)
for page in document:
    pixmap = page.get_pixmap(matrix=pymupdf.Matrix(2, 2), alpha=False)
    display(Image(data=pixmap.tobytes("png")))
document.close()
display(Markdown(f"Generated: `{output_pdf.relative_to(PROJECT_DIR)}`"))

# %%
import os
import shutil
import subprocess
import sys
from pathlib import Path
from IPython.display import Image, Markdown, display

PROJECT_DIR = Path.cwd().resolve()
if not (PROJECT_DIR / "results").is_dir():
    raise RuntimeError(
        "Run this notebook from the EmuRAN-Draft-Artifact project root "
        "(the directory containing the results folder)."
    )
RESULTS_DIR = PROJECT_DIR / "results"
DATA_DIR = RESULTS_DIR / "data"
OUTPUT_DIR = RESULTS_DIR / "output"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
import pymupdf

figure_dir = DATA_DIR / 'fig10d'
plot_script = figure_dir / 'plot_ping_latency_and_dilation.py'
output_pdf = OUTPUT_DIR / 'evaluation-dilation-network-latencies.pdf'
output_pdf.unlink(missing_ok=True)
command = [sys.executable, str(plot_script)] + []
environment = os.environ.copy()
environment["MPLBACKEND"] = "Agg"
display(Markdown('## Draft Figure 10(d) — Dilation under network latency' + f"\n\nRunning `{plot_script.relative_to(PROJECT_DIR)}`…"))
completed = subprocess.run(
    command,
    cwd=figure_dir,
    env=environment,
    text=True,
    capture_output=True,
)
if completed.returncode != 0:
    raise RuntimeError(
        f"Plot script failed with exit code {completed.returncode}:\n"
        f"{completed.stderr.strip() or completed.stdout.strip()}"
    )
if completed.stdout.strip():
    print(completed.stdout.strip())
produced_pdf = figure_dir / 'evaluation-dilation-network-latencies.pdf'
if not produced_pdf.exists():
    raise FileNotFoundError(f"Plot script did not generate {produced_pdf}")
shutil.move(str(produced_pdf), str(output_pdf))
if not output_pdf.exists():
    raise FileNotFoundError(f"Expected generated PDF at {output_pdf}")

document = pymupdf.open(output_pdf)
for page in document:
    pixmap = page.get_pixmap(matrix=pymupdf.Matrix(2, 2), alpha=False)
    display(Image(data=pixmap.tobytes("png")))
document.close()
display(Markdown(f"Generated: `{output_pdf.relative_to(PROJECT_DIR)}`"))

# %%
import os
import shutil
import subprocess
import sys
from pathlib import Path
from IPython.display import Image, Markdown, display

PROJECT_DIR = Path.cwd().resolve()
if not (PROJECT_DIR / "results").is_dir():
    raise RuntimeError(
        "Run this notebook from the EmuRAN-Draft-Artifact project root "
        "(the directory containing the results folder)."
    )
RESULTS_DIR = PROJECT_DIR / "results"
DATA_DIR = RESULTS_DIR / "data"
OUTPUT_DIR = RESULTS_DIR / "output"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
import pymupdf

figure_dir = DATA_DIR / 'fig12'
plot_script = figure_dir / 'plot_ecdf_xapp_combined_v2.py'
output_pdf = OUTPUT_DIR / 'ecdf_xapp_combined_v2.pdf'
output_pdf.unlink(missing_ok=True)
command = [sys.executable, str(plot_script)] + []
environment = os.environ.copy()
environment["MPLBACKEND"] = "Agg"
display(Markdown('## Draft Figure 12(a–d) — UL-RB ECDF and closed-loop xApp OLLA control' + f"\n\nRunning `{plot_script.relative_to(PROJECT_DIR)}`…"))
completed = subprocess.run(
    command,
    cwd=figure_dir,
    env=environment,
    text=True,
    capture_output=True,
)
if completed.returncode != 0:
    raise RuntimeError(
        f"Plot script failed with exit code {completed.returncode}:\n"
        f"{completed.stderr.strip() or completed.stdout.strip()}"
    )
if completed.stdout.strip():
    print(completed.stdout.strip())
produced_pdf = figure_dir / 'ecdf_xapp_combined_v2.pdf'
if not produced_pdf.exists():
    raise FileNotFoundError(f"Plot script did not generate {produced_pdf}")
shutil.move(str(produced_pdf), str(output_pdf))
if not output_pdf.exists():
    raise FileNotFoundError(f"Expected generated PDF at {output_pdf}")

document = pymupdf.open(output_pdf)
for page in document:
    pixmap = page.get_pixmap(matrix=pymupdf.Matrix(2, 2), alpha=False)
    display(Image(data=pixmap.tobytes("png")))
document.close()
display(Markdown(f"Generated: `{output_pdf.relative_to(PROJECT_DIR)}`"))

# %%
import os
import shutil
import subprocess
import sys
from pathlib import Path
from IPython.display import Image, Markdown, display

PROJECT_DIR = Path.cwd().resolve()
if not (PROJECT_DIR / "results").is_dir():
    raise RuntimeError(
        "Run this notebook from the EmuRAN-Draft-Artifact project root "
        "(the directory containing the results folder)."
    )
RESULTS_DIR = PROJECT_DIR / "results"
DATA_DIR = RESULTS_DIR / "data"
OUTPUT_DIR = RESULTS_DIR / "output"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
import pymupdf

figure_dir = DATA_DIR / 'fig15a'
plot_script = figure_dir / 'plot.py'
output_pdf = OUTPUT_DIR / 'cdf_slot_completion_time.pdf'
output_pdf.unlink(missing_ok=True)
command = [sys.executable, str(plot_script)] + ['--output', str(output_pdf)]
environment = os.environ.copy()
environment["MPLBACKEND"] = "Agg"
display(Markdown('## Draft Figure 15(a) — Full-PHY slot-completion times with and without Chronos' + f"\n\nRunning `{plot_script.relative_to(PROJECT_DIR)}`…"))
completed = subprocess.run(
    command,
    cwd=figure_dir,
    env=environment,
    text=True,
    capture_output=True,
)
if completed.returncode != 0:
    raise RuntimeError(
        f"Plot script failed with exit code {completed.returncode}:\n"
        f"{completed.stderr.strip() or completed.stdout.strip()}"
    )
if completed.stdout.strip():
    print(completed.stdout.strip())
if not output_pdf.exists():
    raise FileNotFoundError(f"Expected generated PDF at {output_pdf}")

document = pymupdf.open(output_pdf)
for page in document:
    pixmap = page.get_pixmap(matrix=pymupdf.Matrix(2, 2), alpha=False)
    display(Image(data=pixmap.tobytes("png")))
document.close()
display(Markdown(f"Generated: `{output_pdf.relative_to(PROJECT_DIR)}`"))

# %%
import os
import shutil
import subprocess
import sys
from pathlib import Path
from IPython.display import Image, Markdown, display

PROJECT_DIR = Path.cwd().resolve()
if not (PROJECT_DIR / "results").is_dir():
    raise RuntimeError(
        "Run this notebook from the EmuRAN-Draft-Artifact project root "
        "(the directory containing the results folder)."
    )
RESULTS_DIR = PROJECT_DIR / "results"
DATA_DIR = RESULTS_DIR / "data"
OUTPUT_DIR = RESULTS_DIR / "output"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
import pymupdf

figure_dir = DATA_DIR / 'fig15b'
plot_script = figure_dir / 'plot.py'
output_pdf = OUTPUT_DIR / 'iperf3_speeds_comparison.pdf'
output_pdf.unlink(missing_ok=True)
command = [sys.executable, str(plot_script)] + ['--output', str(output_pdf)]
environment = os.environ.copy()
environment["MPLBACKEND"] = "Agg"
display(Markdown('## Draft Figure 15(b) — Impact of Chronos on throughput' + f"\n\nRunning `{plot_script.relative_to(PROJECT_DIR)}`…"))
completed = subprocess.run(
    command,
    cwd=figure_dir,
    env=environment,
    text=True,
    capture_output=True,
)
if completed.returncode != 0:
    raise RuntimeError(
        f"Plot script failed with exit code {completed.returncode}:\n"
        f"{completed.stderr.strip() or completed.stdout.strip()}"
    )
if completed.stdout.strip():
    print(completed.stdout.strip())
if not output_pdf.exists():
    raise FileNotFoundError(f"Expected generated PDF at {output_pdf}")

document = pymupdf.open(output_pdf)
for page in document:
    pixmap = page.get_pixmap(matrix=pymupdf.Matrix(2, 2), alpha=False)
    display(Image(data=pixmap.tobytes("png")))
document.close()
display(Markdown(f"Generated: `{output_pdf.relative_to(PROJECT_DIR)}`"))

# %%
import os
import shutil
import subprocess
import sys
from pathlib import Path
from IPython.display import Image, Markdown, display

PROJECT_DIR = Path.cwd().resolve()
if not (PROJECT_DIR / "results").is_dir():
    raise RuntimeError(
        "Run this notebook from the EmuRAN-Draft-Artifact project root "
        "(the directory containing the results folder)."
    )
RESULTS_DIR = PROJECT_DIR / "results"
DATA_DIR = RESULTS_DIR / "data"
OUTPUT_DIR = RESULTS_DIR / "output"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
import pymupdf

figure_dir = DATA_DIR / 'fig16'
plot_script = figure_dir / 'plot_fig19.py'
output_pdf = OUTPUT_DIR / 'evaluation-dilation-number-of-nodes.pdf'
output_pdf.unlink(missing_ok=True)
command = [sys.executable, str(plot_script)] + []
environment = os.environ.copy()
environment["MPLBACKEND"] = "Agg"
display(Markdown('## Draft Figure 16 — Dilation overhead as cloud-instance count increases' + f"\n\nRunning `{plot_script.relative_to(PROJECT_DIR)}`…"))
completed = subprocess.run(
    command,
    cwd=figure_dir,
    env=environment,
    text=True,
    capture_output=True,
)
if completed.returncode != 0:
    raise RuntimeError(
        f"Plot script failed with exit code {completed.returncode}:\n"
        f"{completed.stderr.strip() or completed.stdout.strip()}"
    )
if completed.stdout.strip():
    print(completed.stdout.strip())
produced_pdf = figure_dir / 'evaluation-dilation-number-of-nodes.pdf'
if not produced_pdf.exists():
    raise FileNotFoundError(f"Plot script did not generate {produced_pdf}")
shutil.move(str(produced_pdf), str(output_pdf))
if not output_pdf.exists():
    raise FileNotFoundError(f"Expected generated PDF at {output_pdf}")

document = pymupdf.open(output_pdf)
for page in document:
    pixmap = page.get_pixmap(matrix=pymupdf.Matrix(2, 2), alpha=False)
    display(Image(data=pixmap.tobytes("png")))
document.close()
display(Markdown(f"Generated: `{output_pdf.relative_to(PROJECT_DIR)}`"))

# %%
import os
import shutil
import subprocess
import sys
from pathlib import Path
from IPython.display import Image, Markdown, display

PROJECT_DIR = Path.cwd().resolve()
if not (PROJECT_DIR / "results").is_dir():
    raise RuntimeError(
        "Run this notebook from the EmuRAN-Draft-Artifact project root "
        "(the directory containing the results folder)."
    )
RESULTS_DIR = PROJECT_DIR / "results"
DATA_DIR = RESULTS_DIR / "data"
OUTPUT_DIR = RESULTS_DIR / "output"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
import pymupdf

figure_dir = DATA_DIR / 'fig17'
plot_script = figure_dir / 'plot.py'
output_pdf = OUTPUT_DIR / 'epoll.pdf'
output_pdf.unlink(missing_ok=True)
command = [sys.executable, str(plot_script)] + []
environment = os.environ.copy()
environment["MPLBACKEND"] = "Agg"
display(Markdown('## Draft Figure 17 — Middlebox epoll scaling penalty' + f"\n\nRunning `{plot_script.relative_to(PROJECT_DIR)}`…"))
completed = subprocess.run(
    command,
    cwd=figure_dir,
    env=environment,
    text=True,
    capture_output=True,
)
if completed.returncode != 0:
    raise RuntimeError(
        f"Plot script failed with exit code {completed.returncode}:\n"
        f"{completed.stderr.strip() or completed.stdout.strip()}"
    )
if completed.stdout.strip():
    print(completed.stdout.strip())
produced_pdf = figure_dir / 'epoll.pdf'
if not produced_pdf.exists():
    raise FileNotFoundError(f"Plot script did not generate {produced_pdf}")
shutil.move(str(produced_pdf), str(output_pdf))
if not output_pdf.exists():
    raise FileNotFoundError(f"Expected generated PDF at {output_pdf}")

document = pymupdf.open(output_pdf)
for page in document:
    pixmap = page.get_pixmap(matrix=pymupdf.Matrix(2, 2), alpha=False)
    display(Image(data=pixmap.tobytes("png")))
document.close()
display(Markdown(f"Generated: `{output_pdf.relative_to(PROJECT_DIR)}`"))

# %%
import os
import shutil
import subprocess
import sys
from pathlib import Path
from IPython.display import Image, Markdown, display

PROJECT_DIR = Path.cwd().resolve()
if not (PROJECT_DIR / "results").is_dir():
    raise RuntimeError(
        "Run this notebook from the EmuRAN-Draft-Artifact project root "
        "(the directory containing the results folder)."
    )
RESULTS_DIR = PROJECT_DIR / "results"
DATA_DIR = RESULTS_DIR / "data"
OUTPUT_DIR = RESULTS_DIR / "output"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
import pymupdf

figure_dir = DATA_DIR / 'fig18'
plot_script = figure_dir / 'plot_dilation_factor_underload.py'
output_pdf = OUTPUT_DIR / 'dilation_factor_underload.pdf'
output_pdf.unlink(missing_ok=True)
command = [sys.executable, str(plot_script)] + ['--output', str(output_pdf)]
environment = os.environ.copy()
environment["MPLBACKEND"] = "Agg"
display(Markdown('## Draft Figure 18 — Dynamic dilation factor under varying compute demand' + f"\n\nRunning `{plot_script.relative_to(PROJECT_DIR)}`…"))
completed = subprocess.run(
    command,
    cwd=figure_dir,
    env=environment,
    text=True,
    capture_output=True,
)
if completed.returncode != 0:
    raise RuntimeError(
        f"Plot script failed with exit code {completed.returncode}:\n"
        f"{completed.stderr.strip() or completed.stdout.strip()}"
    )
if completed.stdout.strip():
    print(completed.stdout.strip())
if not output_pdf.exists():
    raise FileNotFoundError(f"Expected generated PDF at {output_pdf}")

document = pymupdf.open(output_pdf)
for page in document:
    pixmap = page.get_pixmap(matrix=pymupdf.Matrix(2, 2), alpha=False)
    display(Image(data=pixmap.tobytes("png")))
document.close()
display(Markdown(f"Generated: `{output_pdf.relative_to(PROJECT_DIR)}`"))

# %%
import os
import shutil
import subprocess
import sys
from pathlib import Path
from IPython.display import Image, Markdown, display

PROJECT_DIR = Path.cwd().resolve()
if not (PROJECT_DIR / "results").is_dir():
    raise RuntimeError(
        "Run this notebook from the EmuRAN-Draft-Artifact project root "
        "(the directory containing the results folder)."
    )
RESULTS_DIR = PROJECT_DIR / "results"
DATA_DIR = RESULTS_DIR / "data"
OUTPUT_DIR = RESULTS_DIR / "output"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
import pymupdf

figure_dir = DATA_DIR / 'fig19'
plot_script = figure_dir / 'plot_4g_bar.py'
output_pdf = OUTPUT_DIR / 'fig_4g_enb_ue_scalability.pdf'
output_pdf.unlink(missing_ok=True)
command = [sys.executable, str(plot_script)] + []
environment = os.environ.copy()
environment["MPLBACKEND"] = "Agg"
display(Markdown('## Draft Figure 19 — 4G LTE eNB/UE scaling at 100 UEs per eNB' + f"\n\nRunning `{plot_script.relative_to(PROJECT_DIR)}`…"))
completed = subprocess.run(
    command,
    cwd=figure_dir,
    env=environment,
    text=True,
    capture_output=True,
)
if completed.returncode != 0:
    raise RuntimeError(
        f"Plot script failed with exit code {completed.returncode}:\n"
        f"{completed.stderr.strip() or completed.stdout.strip()}"
    )
if completed.stdout.strip():
    print(completed.stdout.strip())
produced_pdf = figure_dir / 'fig_4g_enb_ue_scalability.pdf'
if not produced_pdf.exists():
    raise FileNotFoundError(f"Plot script did not generate {produced_pdf}")
shutil.move(str(produced_pdf), str(output_pdf))
if not output_pdf.exists():
    raise FileNotFoundError(f"Expected generated PDF at {output_pdf}")

document = pymupdf.open(output_pdf)
for page in document:
    pixmap = page.get_pixmap(matrix=pymupdf.Matrix(2, 2), alpha=False)
    display(Image(data=pixmap.tobytes("png")))
document.close()
display(Markdown(f"Generated: `{output_pdf.relative_to(PROJECT_DIR)}`"))
